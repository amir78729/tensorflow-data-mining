# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt
# import tensorflow as tf
import pandas as pd

# %% [markdown]
# <div dir="rtl">
# ابتدا مجموعه‌داده‌ی گفته شده را دریافت می‌کنیم و داده‌های آن را هم در جدول و هم در نمودار پراکندگی نمایش می‌دهیم:
# </div>

# %%
data, lables = make_circles(
    1000, 
    noise=0.05, 
    factor=0.5,
    random_state=1
)
circle = pd.DataFrame({
    'x': data[:, 0], 
    'y': data[:, 1], 
    'label': lables
})
circle
# Out:
#             x         y  label
# 0    0.563552 -0.013824      1
# 1   -0.337174 -0.452649      1
# 2    0.874093 -0.641097      0
# 3   -0.095011 -0.944484      0
# 4   -1.006072  0.173870      0
# ..        ...       ...    ...
# 995 -0.430505 -0.174546      1
# 996  0.663198  0.793716      0
# 997  0.193894 -0.407036      1
# 998 -0.955325  0.127157      0
# 999  0.964432  0.498583      0
#
# [1000 rows x 3 columns]

# %%
plt.scatter(data[:,0], data[:,1], c=y, alpha=0.5)
plt.title('Circles')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
